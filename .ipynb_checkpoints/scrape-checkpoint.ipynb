# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import pandas as pd

# %%
url = "https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1210001101&cubeTimeFrame.startMonth=01&cubeTimeFrame.startYear=1997&cubeTimeFrame.endMonth=07&cubeTimeFrame.endYear=2023&referencePeriods=19970101%2C20230701"

# %%
PATH = '/Applications/Google\ Chrome.app/Contents/MacOS/Google\ Chrome'
driver = webdriver.Chrome(service=Service(executable_path=PATH))
driver.get(url)    
driver.implicitly_wait(5)
page_source = driver.page_source
driver.close()
driver.quit()
# Out:
# Incompatible release of chromedriver (version 115.0.5790.102) detected in PATH: /opt/homebrew/bin/chromedriver

# %% [markdown]
# # Reset Dataframe

# %%
tables = pd.read_html(page_source)
df = tables[0]
df.head()
# Out:
#             Geography                                   Canada (map)  \
#                 Basis                            Balance of payments
#   Seasonal adjustment                            Seasonally adjusted
#                 Trade Principal trading partners        January 1997
# 0                 NaN                        NaN                 NaN
# 1              Import                        NaN             Dollars
# 2              Import              All countries             21837.7
# 3              Import              United States             16452.4
# 4              Import            European Union5              1972.6
#
#                                                                     \
#
#
#   February 1997 March 1997 April 1997 May 1997 June 1997 July 1997
# 0           NaN        NaN        NaN      NaN       NaN       NaN
# 1       Dollars    Dollars    Dollars  Dollars   Dollars   Dollars
# 2       21755.0    21839.5    22620.9  22747.5   22882.5   23467.3
# ...

# %% [markdown]
# # Remove Higher Column Headers

# %%
for i in range(3):
    df.columns = df.columns.droplevel(0)
df.head()
# Out:
#     Trade Principal trading partners January 1997 February 1997 March 1997  \
# 0     NaN                        NaN          NaN           NaN        NaN
# 1  Import                        NaN      Dollars       Dollars    Dollars
# 2  Import              All countries      21837.7       21755.0    21839.5
# 3  Import              United States      16452.4       16603.8    16716.3
# 4  Import            European Union5       1972.6        1726.8     1920.4
#
#   April 1997 May 1997 June 1997 July 1997 August 1997  ... September 2022  \
# 0        NaN      NaN       NaN       NaN         NaN  ...            NaN
# 1    Dollars  Dollars   Dollars   Dollars     Dollars  ...        Dollars
# 2    22620.9  22747.5   22882.5   23467.3     23592.4  ...        65386.4
# 3    17029.6  17057.4   17617.3   17967.1     17997.7  ...        40763.1
# 4     2159.8   2327.1    1944.3    1999.5      1896.5  ...         6227.4
#
# ...

# %% [markdown]
# # Remove N/A values and 'Dollar' Rows

# %%
df = df.drop(index=[0,1])
df.reset_index(drop = True,inplace=True)
df.head()
# Out:
#     Trade Principal trading partners January 1997 February 1997 March 1997  \
# 0  Import              All countries      21837.7       21755.0    21839.5
# 1  Import              United States      16452.4       16603.8    16716.3
# 2  Import            European Union5       1972.6        1726.8     1920.4
# 3  Import                      China        174.3         169.6      143.0
# 4  Import             United Kingdom        529.4         461.5      497.1
#
#   April 1997 May 1997 June 1997 July 1997 August 1997  ... September 2022  \
# 0    22620.9  22747.5   22882.5   23467.3     23592.4  ...        65386.4
# 1    17029.6  17057.4   17617.3   17967.1     17997.7  ...        40763.1
# 2     2159.8   2327.1    1944.3    1999.5      1896.5  ...         6227.4
# 3      164.8    173.3     184.6     196.8       218.4  ...         6135.4
# 4      574.3    478.8     520.5     478.5       440.1  ...          751.2
#
# ...

# %% [markdown]
# # Data Model

# %%
data = {
    'date': 'Jan 1997',
    'country': 'United States',
    'trade_type': 'Import',
    'value': 1234.5
    }

# %% [markdown]
# # Remove NaN value in Trade Column

# %%
df.Trade.unique()
# Out:
# array(['Import', 'Export', 'Trade Balance', nan], dtype=object)

# %%
df[df['Trade'].isnull()]
# Out:
#    Trade Principal trading partners January 1997 February 1997 March 1997  \
# 18   NaN                        NaN          NaN           NaN        NaN
#
#    April 1997 May 1997 June 1997 July 1997 August 1997  ... September 2022  \
# 18        NaN      NaN       NaN       NaN         NaN  ...            NaN
#
#    October 2022 November 2022 December 2022 January 2023 February 2023  \
# 18          NaN           NaN           NaN          NaN           NaN
#
#    March 2023 April 2023 May 2023 June 2023
# 18        NaN        NaN      NaN       NaN
#
# [1 rows x 320 columns]

# %%
index = df.loc[df.Trade.isnull()].index[0]
df = df.drop(index= index)
df.reset_index(drop=True,inplace = True)
df.Trade.unique()
# Out:
# array(['Import', 'Export', 'Trade Balance'], dtype=object)

# %%
df.columns
# Out:
# Index(['Trade', 'Principal trading partners', 'January 1997', 'February 1997',
#        'March 1997', 'April 1997', 'May 1997', 'June 1997', 'July 1997',
#        'August 1997',
#        ...
#        'September 2022', 'October 2022', 'November 2022', 'December 2022',
#        'January 2023', 'February 2023', 'March 2023', 'April 2023', 'May 2023',
#        'June 2023'],
#       dtype='object', length=320)

# %%
len(df)
# Out:
# 18

# %%
df
# Out:
#             Trade Principal trading partners January 1997 February 1997  \
# 0          Import              All countries      21837.7       21755.0
# 1          Import              United States      16452.4       16603.8
# 2          Import            European Union5       1972.6        1726.8
# 3          Import                      China        174.3         169.6
# 4          Import             United Kingdom        529.4         461.5
# 5          Import                     Mexico        320.4         354.7
# 6          Export              All countries      24928.5       24695.9
# 7          Export              United States      19871.6       19717.4
# 8          Export            European Union5       1403.3        1397.1
# 9          Export                      China        283.5         189.2
# 10         Export             United Kingdom        390.7         382.1
# 11         Export                     Mexico        128.5         132.0
# ...

# %% [markdown]
# # Replaced 'Principal trading partners' column name

# %%
df.columns = ['Trading_Partner' if c == 'Principal trading partners' else c  for c in df.columns]

# %%
df.columns
# Out:
# Index(['Trade', 'Trading_Partner', 'January 1997', 'February 1997',
#        'March 1997', 'April 1997', 'May 1997', 'June 1997', 'July 1997',
#        'August 1997',
#        ...
#        'September 2022', 'October 2022', 'November 2022', 'December 2022',
#        'January 2023', 'February 2023', 'March 2023', 'April 2023', 'May 2023',
#        'June 2023'],
#       dtype='object', length=320)

# %%
for index in range(len(df)):
    for month in list(df.columns)[2:]:
        df.at[index, month] = float(df.at[index, month])

# %%
df.Trading_Partner.unique()
# Out:
# array(['All countries', 'United States', 'European Union5', 'China',
#        'United Kingdom', 'Mexico'], dtype=object)

# %%
countries_list = ['United States', 'European Union5', 'China',
       'United Kingdom', 'Mexico']
df.loc[(df.Trading_Partner == 'All countries') & (df.Trade == 'Import')].values[0][2:]
val =df.loc[(df.Trading_Partner.isin(countries_list)) & (df.Trade == 'Import')].sum()[2:]
val
# Out:
# January 1997     19449.1
# February 1997    19316.4
# March 1997       19575.6
# April 1997       20270.1
# May 1997         20354.6
#                   ...
# February 2023    55463.8
# March 2023       54221.5
# April 2023       54155.2
# May 2023         55140.4
# June 2023        55261.6
# Length: 318, dtype: object

# %%
countries_list = ['United States', 'European Union5', 'China',
       'United Kingdom', 'Mexico']
for trade_type in list(df.Trade.unique()):
    
    sum_all = df.loc[(df.Trading_Partner == 'All countries') & (df.Trade == str(trade_type))].values[0][2:]
    sum_others = df.loc[(df.Trading_Partner.isin(countries_list)) & (df.Trade == trade_type)].sum()[2:]
    
    sum_all_float = [float(val) for val in sum_all]
    sum_others_float = [float(val) for val in sum_others]
    difference = list(map(lambda x, y : x-y, sum_all_float, sum_others_float))
    new_row = [trade_type, "Others"] +  difference
    df.loc[len(df)] = new_row

# %%
df
# Out:
#             Trade  Trading_Partner January 1997 February 1997 March 1997  \
# 0          Import    All countries      21837.7       21755.0    21839.5
# 1          Import    United States      16452.4       16603.8    16716.3
# 2          Import  European Union5       1972.6        1726.8     1920.4
# 3          Import            China        174.3         169.6      143.0
# 4          Import   United Kingdom        529.4         461.5      497.1
# 5          Import           Mexico        320.4         354.7      298.8
# 6          Export    All countries      24928.5       24695.9    24535.9
# 7          Export    United States      19871.6       19717.4    19307.5
# 8          Export  European Union5       1403.3        1397.1     1426.8
# 9          Export            China        283.5         189.2      267.1
# 10         Export   United Kingdom        390.7         382.1      393.1
# 11         Export           Mexico        128.5         132.0      194.2
# ...

# %%
from datetime import datetime
data = {'data' : []}
for index,row in df.iterrows():
    for date  in df.columns[2:]:
        data['data'].append({
            'date': datetime.strptime(date, '%B %Y'),
            'trade_type': row.Trade,
            'trading_partner': row.Trading_Partner,
            'value': float(row[date])
        })
data['data'][0]
# Out:
# {'date': datetime.datetime(1997, 1, 1, 0, 0),
#  'trade_type': 'Import',
#  'trading_partner': 'All countries',
#  'value': 21837.7}

# %%
len(data['data'])
data['data'][:10]
# Out:
# [{'date': datetime.datetime(1997, 1, 1, 0, 0),
#   'trade_type': 'Import',
#   'trading_partner': 'All countries',
#   'value': 21837.7,
#   '_id': ObjectId('64d3b902d9f5e02d15447cc2')},
#  {'date': datetime.datetime(1997, 2, 1, 0, 0),
#   'trade_type': 'Import',
#   'trading_partner': 'All countries',
#   'value': 21755.0,
#   '_id': ObjectId('64d3b902d9f5e02d15447cc3')},
#  {'date': datetime.datetime(1997, 3, 1, 0, 0),
#   'trade_type': 'Import',
#   'trading_partner': 'All countries',
#   'value': 21839.5,
#   '_id': ObjectId('64d3b902d9f5e02d15447cc4')},
#  {'date': datetime.datetime(1997, 4, 1, 0, 0),
#   'trade_type': 'Import',
#   'trading_partner': 'All countries',
#   'value': 22620.9,
#   '_id': ObjectId('64d3b902d9f5e02d15447cc5')},
#  {'date': datetime.datetime(1997, 5, 1, 0, 0),
#   'trade_type': 'Import',
#   'trading_partner': 'All countries',
#   'value': 22747.5,
#   '_id': ObjectId('64d3b902d9f5e02d15447cc6')},
#  {'date': datetime.datetime(1997, 6, 1, 0, 0),
# ...

# %%
import json

# %%
#with open('data.json','w') as file:
    #json.dump(data,file)

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://kamal:kamal@cluster0.ckharmj.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client["BDAT1004"]
collection = db["Group_7"]


print("Keys in the data:", data.keys())
print("First item:", data[list(data.keys())[0]][0])
# Out:
# Keys in the data: dict_keys(['data'])
# First item: {'date': datetime.datetime(1997, 1, 1, 0, 0), 'trade_type': 'Import', 'trading_partner': 'All countries', 'value': 21837.7}

# %% [markdown]
# # Insert Data into MongoDB Database

# %%
content = data['data']
collection.insert_many(content) #uncomment this for inserting data for first time
